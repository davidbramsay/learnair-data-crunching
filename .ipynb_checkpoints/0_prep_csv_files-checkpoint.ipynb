# %%
#pull data from CSVs and plot with matplotlib

#step 1. go into file and make sure we don't have extraneous readings at beginning or end
#  deleted rows at end of boxArduino042516
#  row 57416 in boxArduino052316 there was a glitch/reset. (5/15/16 14:25)  Readings move forward in time 2 sec (so 
#  shorter interval) and the next reading is bogus.  deleted glitch titles and replaced bogus reading with avg of two.

#step 2. fix timestamps using ~/Python/learnAirDataPush/changeExcelTimeStamps.py
#  for first set we change the start/end time to 6:13:20 4/15/16 to 14:20:00 4/25/16
#  for second set we change the start/end time to 15:00:00 4/25/16 to 21:20:00 5/23/16

print '------------------------------------------------------------------------------------------------------'        
print '--- 6:13:20 4/15/16 to 14:20:00 4/25/16 --- \n10 days, 8 hours, 6 min, 40 seconds actually plugged in'

total_expected_samples = (10*(24*60*2) + 8*(60*2) + 6*(2) + 1) + 1
print 'total expected samples @ 30 sec intervals = %s (%s min) \n' % (total_expected_samples, total_expected_samples/2.0)

off_by = total_expected_samples - 29715
print 'Actual samples from Arduino = 29,715.  Off by %s samples / %s min, or %s %% drift. \n' % (off_by, off_by/2.0, 100.0*off_by/total_expected_samples)

'''
-- SELECTED /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown042516/boxArduino042516.CSV
start time: 2016/4/15 6:14:14 
end time: 2016/4/25 14:19:3
---
Provide actual start time of measurement: 6:13:20 4/15/16
Provide actual end time of measurement: 14:20:00 4/25/16
-----------------------------------------------
start time diff: -1 day, 23:59:06
end time diff: 0:00:57
-----------------------------------------------
duration original: 10 days, 8:04:49
duration actual: 10 days, 8:06:40
duration diff: 0:01:51
-----------------------------------------------
UPDATING TIMESTAMPS TO RUN FROM 04/15/16 06:13:20 TO 04/25/16 14:20:00 WITH STEP 0:00:30.058892
-----------------------------------------------
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown042516/boxArduino042516_fixed_timestamps.csv
Desired Interval in Seconds [30]
Desired Snap, 0=interpolate, 1=nearest [0]0
snap_start: 04/15/16 06:13:00
snap_end: 04/25/16 14:20:30
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown042516/boxArduino042516_interp.csv
------------------------------------------------------------
'''
print 'Updated timestamps to match plugged in time. \nRecorded time difference is only 1min 51sec.  Measurement step is 30.059s \n'
print 'Interpolated values for actual thirty second increments, gone from "real vals" to 29,776 values \n' + \
      'starting at 04/15/16 06:13:00 and ending at 04/25/16 14:20:30 \n' + \
      'saved in: thesis/arduinoDataSafe/cleanedData/takenDown042516/boxArduino042516_interp.csv \n'

off_by = total_expected_samples - 29698
print 'Actual samples from SCK = 29,698.  Off by %s samples / %s min, or %s %% drift. \n' % (off_by, off_by/2.0, 100.0*off_by/total_expected_samples)

'''
-- SELECTED /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown042516/boxSmartCitizen042516.csv
start time: 2000-01-01 00:00:37 
end time: 2000-01-11 08:05:23
---
Provide actual start time of measurement: 6:13:20 4/15/16
Provide actual end time of measurement: 14:20:00 4/25/16
-----------------------------------------------
start time diff: 5949 days, 6:12:43
end time diff: 5949 days, 6:14:37
-----------------------------------------------
duration original: 10 days, 8:04:46
duration actual: 10 days, 8:06:40
duration diff: 0:01:54
-----------------------------------------------
UPDATING TIMESTAMPS TO RUN FROM 04/15/16 06:13:20 TO 04/25/16 14:20:00 WITH STEP 0:00:30.076099
-----------------------------------------------
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown042516/boxSmartCitizen042516_fixed_timestamps.csv
Desired Interval in Seconds [30]
Desired Snap, 0=interpolate, 1=nearest [0]
snap_start: 04/15/16 06:13:00
snap_end: 04/25/16 14:20:30
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown042516/boxSmartCitizen042516_interp.csv
------------------------------------------------------------
'''
print 'Updated timestamps to match plugged in time. \nRecorded time difference is only 1min 54sec.  Measurement step is 30.076s \n'
print 'Interpolated values for actual thirty second increments, gone from "real vals" to 29,776 values \n' + \
      'starting at 04/15/16 06:13:00 and ending at 04/25/16 14:20:30 \n' + \
      'saved in: thesis/arduinoDataSafe/cleanedData/takenDown042516/boxSmartCitizen042516_interp.csv \n'

print '------------------------------------------------------------------------------------------------------'        
print '--- 15:00:00 4/25/16 to 21:20:00 5/23/16 --- \n28 days, 6 hours, 20 min actually plugged in'

total_expected_samples = (28*(24*60*2) + 6*(60*2) + 20*(2)) + 1
print 'total expected samples @ 30 sec intervals = %s (%s min) \n' % (total_expected_samples, total_expected_samples/2.0)

off_by = total_expected_samples - 81226
print 'Actual samples from Arduino = 81,226.  Off by %s samples / %s min, or %s %% drift. \n' % (off_by, off_by/2.0, 100.0*off_by/total_expected_samples)

'''
-- SELECTED /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown052316/boxArduino052316.CSV
start time: 2016/4/25 15:0:12 
end time: 2016/5/23 21:20:12
---
Provide actual start time of measurement: 15:00:00 4/25/16
Provide actual end time of measurement: 21:20:00 5/23/16
-----------------------------------------------
start time diff: -1 day, 23:59:48
end time diff: -1 day, 23:59:48
-----------------------------------------------
duration original: 28 days, 6:20:00
duration actual: 28 days, 6:20:00
duration diff: 0:00:00
-----------------------------------------------
UPDATING TIMESTAMPS TO RUN FROM 04/25/16 15:00:00 TO 05/23/16 21:20:00 WITH STEP 0:00:30.064265
-----------------------------------------------
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown052316/boxArduino052316_fixed_timestamps.csv
Desired Interval in Seconds [30]
Desired Snap, 0=interpolate, 1=nearest [0]
snap_start: 04/25/16 15:00:00
snap_end: 05/23/16 21:20:30
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown052316/boxArduino052316_interp.csv
------------------------------------------------------------
'''
print 'Updated timestamps to match plugged in time. \nRecorded time difference is 0sec.  Measurement step is 30.064s \n'
print 'Interpolated values for actual thirty second increments, gone from "real vals" to 81,402 values \n' + \
      'starting at 04/25/16 15:00:00 and ending at 05/23/16 21:20:30 \n' + \
      'saved in: thesis/arduinoDataSafe/cleanedData/takenDown052316/boxArduino052316_interp.csv \n'

off_by = total_expected_samples - 81204
print 'Actual samples from SCK = 81,204.  Off by %s samples / %s min, or %s %% drift. \n' % (off_by, off_by/2.0, 100.0*off_by/total_expected_samples)

'''
-- SELECTED /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown052316/boxSmartCitizen052316.csv
start time: 2000-01-11 08:47:07 
end time: 2000-02-08 15:07:56
---
Provide actual start time of measurement: 15:00:00 4/25/16
Provide actual end time of measurement: 21:20:00 5/23/16
-----------------------------------------------
start time diff: 5949 days, 6:12:53
end time diff: 5949 days, 6:12:04
-----------------------------------------------
duration original: 28 days, 6:20:49
duration actual: 28 days, 6:20:00
duration diff: -1 day, 23:59:11
-----------------------------------------------
UPDATING TIMESTAMPS TO RUN FROM 04/25/16 15:00:00 TO 05/23/16 21:20:00 WITH STEP 0:00:30.072410
-----------------------------------------------
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown052316/boxSmartCitizen052316_fixed_timestamps.csv
Desired Interval in Seconds [30]
Desired Snap, 0=interpolate, 1=nearest [0]
snap_start: 04/25/16 15:00:00
snap_end: 05/23/16 21:20:30
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown052316/boxSmartCitizen052316_interp.csv
------------------------------------------------------------
'''
print 'Updated timestamps to match plugged in time. \nRecorded time difference is 49sec.  Measurement step is 30.072s \n'
print 'Interpolated values for actual thirty second increments, gone from "real vals" to 81,402 values \n' + \
      'starting at 04/25/16 15:00:00 and ending at 05/23/16 21:20:30 \n' + \
      'saved in: thesis/arduinoDataSafe/cleanedData/takenDown052316/boxSmartCitizen052316_interp.csv \n'

        
        
print '------------------------------------------------------------------------------------------------------'        
print '--- 22:01:00 5/23/16 to 20:30:00 6/13/16 --- \n20 days, 22 hours, 29 min actually plugged in'

total_expected_samples = (20*(24*60*2) + 22*(60*2) + 29*(2)) + 1
print 'total expected samples @ 30 sec intervals = %s (%s min) \n' % (total_expected_samples, total_expected_samples/2.0)

print 'total samples from Arduino = 60,140'

'''
-- SELECTED /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316/boxArduino061316.CSV
start time: 2016/5/23 22:9:13 
end time: 2016/6/13 10:8:38
---
Provide actual start time of measurement: 22:01:00 5/23/16
Provide actual end time of measurement: 20:30:00 6/13/16
-----------------------------------------------
start time diff: -1 day, 23:51:47
end time diff: 10:21:22
-----------------------------------------------
duration original: 20 days, 11:59:25
duration actual: 20 days, 22:29:00
duration diff: 10:29:35
-----------------------------------------------
UPDATING TIMESTAMPS TO RUN FROM 05/23/16 22:01:00 TO 06/13/16 20:30:00 WITH STEP 0:00:30.078816
-----------------------------------------------
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316/boxArduino061316_fixed_timestamps.csv
Desired Interval in Seconds [30]
Desired Snap, 0=interpolate, 1=nearest [0]
snap_start: 05/23/16 22:01:00
snap_end: 06/13/16 20:30:30
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316/boxArduino061316_interp.csv
------------------------------------------------------------
'''
print 'Updated timestamps to match plugged in time. \nRecorded time difference is 10hr30sec.  Measurement step is 30.079s \n'
print 'Interpolated values for actual thirty second increments, gone from "real vals" to 60,300 values \n' + \
      'starting at 05/23/16 22:01:00 and ending at 06/13/16 20:30:30 \n' + \
      'saved in: thesis/arduinoDataSafe/cleanedData/takenDown061316/boxArduino061316_interp.csv \n'

print 'despite disconcerting and much larger drift in actual timestamp values for arduino (10hours, when previously\n' + \
      'we were off by <1 min for similar # of samples), the arduino was still working when taken down, and the actual\n' + \
      'measurement step/# samples was very in line with previous installs (30.079s vs 30.072s in previous)'

print 'This all suggests that the samples we have run the entire range of the measurement, and that"s how they"ve been\n' + \
      'processed.  There is a chance that the actual timestamps were correct, in which case we may have stretched the data\n' + \
      'out over an extra 10 hours.  Be aware when plotting and compare.'
        
'''
JUST IN CASE: I've made one that matches the duration of the timestamps reported by the RTC, but that is fixed to start
at the right time.  It lives in 'arduinoUsingRTCTimestamps'

-- SELECTED /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316/arduinoUsingRTCTimestamps/boxArduino061316.CSV
start time: 2016/5/23 22:9:13 
end time: 2016/6/13 10:8:38
---
Provide actual start time of measurement: 22:01:00 5/23/16
Provide actual end time of measurement: 10:0:25 6/13/16
-----------------------------------------------
start time diff: -1 day, 23:51:47
end time diff: -1 day, 23:51:47
-----------------------------------------------
duration original: 20 days, 11:59:25
duration actual: 20 days, 11:59:25
duration diff: 0:00:00
-----------------------------------------------
UPDATING TIMESTAMPS TO RUN FROM 05/23/16 22:01:00 TO 06/13/16 10:00:25 WITH STEP 0:00:29.450698
-----------------------------------------------
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316/arduinoUsingRTCTimestamps/boxArduino061316_fixed_timestamps.csv
Desired Interval in Seconds [30]
Desired Snap, 0=interpolate, 1=nearest [0]
snap_start: 05/23/16 22:01:00
snap_end: 06/13/16 10:00:30
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316/arduinoUsingRTCTimestamps/boxArduino061316_interp.csv
------------------------------------------------------------
'''        


print 'total samples from SCK = 38,646'
print 'SCK showed serious signs of corrosion, clearly crapped out halfway though'
print 'to use this data, we assume it started collection at the right time, and we assume the same effective\n' + \
      'measurement delay (30.076 and 30.072, so assume 30.074s).  Start at 05/23/16 22:01:00, end at start + 30.074*#measurements'

#30.074s * 38,646 = 1,162,239.804 sec of measurement - 06/06/16 8:51:40

'''
-- SELECTED /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316/boxSmartCitizen061316.csv
start time: 2000-02-08 15:57:32 
end time: 2000-02-22 02:46:09
---
Provide actual start time of measurement: 05/23/16 22:01:00
Provide actual end time of measurement: 06/06/16 8:51:40
-----------------------------------------------
start time diff: 5949 days, 6:03:28
end time diff: 5949 days, 6:05:31
-----------------------------------------------
duration original: 13 days, 10:48:37
duration actual: 13 days, 10:50:40
duration diff: 0:02:03
-----------------------------------------------
UPDATING TIMESTAMPS TO RUN FROM 05/23/16 22:01:00 TO 06/06/16 08:51:40 WITH STEP 0:00:30.074005
-----------------------------------------------
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316/boxSmartCitizen061316_fixed_timestamps.csv
Desired Interval in Seconds [30]
Desired Snap, 0=interpolate, 1=nearest [0]
snap_start: 05/23/16 22:01:00
snap_end: 06/06/16 08:52:00
writing to /Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316/boxSmartCitizen061316_interp.csv
------------------------------------------------------------
'''
# Out:
# ------------------------------------------------------------------------------------------------------
# --- 6:13:20 4/15/16 to 14:20:00 4/25/16 ---
# 10 days, 8 hours, 6 min, 40 seconds actually plugged in
# total expected samples @ 30 sec intervals = 29774 (14887.0 min)
#
# Actual samples from Arduino = 29,715.  Off by 59 samples / 29.5 min, or 0.198159467992 % drift.
#
# Updated timestamps to match plugged in time.
# Recorded time difference is only 1min 51sec.  Measurement step is 30.059s
#
# Interpolated values for actual thirty second increments, gone from "real vals" to 29,776 values
# starting at 04/15/16 06:13:00 and ending at 04/25/16 14:20:30
# saved in: thesis/arduinoDataSafe/cleanedData/takenDown042516/boxArduino042516_interp.csv
#
# Actual samples from SCK = 29,698.  Off by 76 samples / 38.0 min, or 0.255256263854 % drift.
#
# Updated timestamps to match plugged in time.
# Recorded time difference is only 1min 54sec.  Measurement step is 30.076s
#
# ...

# %%
files2 = [ '/Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown052316/boxSmartCitizen052316_interp.csv',
          '/Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown052316/boxArduino052316_interp.csv',
          '/Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown042516/boxSmartCitizen042516_interp.csv',
          '/Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown042516/boxArduino042516_interp.csv',
          '/Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316arduino/boxArduino061316_interp.csv',
          '/Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316fullset/boxArduino061316_interp.csv',
          '/Users/davidramsay/Documents/thesis/arduinoDataSafe/cleanedData/takenDown061316fullset/boxSmartCitizen061316_interp.csv']        ]
'''
#loop through files and make min versions instead of 30 second versions
for file in files:
    file2 = open(file[:-4] + 'min.csv', 'a+')
    with open(file) as f:
        for i, line in enumerate(f):
             if i % 2 == 1 or i == 0:
                 file2.write(line)
    file2.close()
'''

#create array of filenames with minute resolution
files_min = [file[:-4] + 'min.csv' for file in files]

# %% [markdown]
# Now we have 111,178 interpolated, corrected values that are on the :00 and :30 second marks.
# Or 55,589 interpolated, corrected values on a per second basis.
#
# Creating pruned csvs from EPA outside of python, in cleanedData/EPA 14888
